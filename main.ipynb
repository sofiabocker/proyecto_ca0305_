# %%
# Importar módulo necesario
from cod.python.Modelos import Modelo
precios_casas = Modelo()

# Cargar la data de Egipto
precios_casas.cargar_data_Egipto()

# Imprimir la data
precios_casas.get_data()
# Out:
#          Type    Price Bedrooms Bathrooms   Area Furnished    Level  \
# 0      Duplex  4000000      3.0       3.0  400.0        No        7
# 1   Apartment  4000000      3.0       3.0  160.0        No      10+
# 2   Apartment  2250000      3.0       2.0  165.0        No        1
# 3   Apartment  1900000      3.0       2.0  230.0        No       10
# 4   Apartment  5800000      2.0       3.0  160.0        No   Ground
# 5   Apartment  1844900      4.0       3.0  222.0        No        1
# 6      Duplex  3900000      5.0       5.0  290.0        No  Highest
# 7   Apartment  1650000      2.0       2.0  144.0        No        1
# 8   Apartment  1560000      3.0       3.0  200.0   Unknown   Ground
# 9   Apartment   992800      3.0       2.0  146.0   Unknown        3
# 10  Apartment   309825      4.0       3.0  153.0        No        1
# 11  Apartment  1150000      3.0       2.0  165.0        No        2
# 12  Apartment   550000      2.0       1.0   94.0        No        2
# ...

# %%
# Limpiar la data
precios_casas.limpiar_data()

# %%
# Imprimir la data limpia
precios_casas.get_data()
# Out:
#          Type      Price  Bedrooms  Bathrooms   Area
# 0      Duplex  4000000.0       3.0        3.0  400.0
# 1   Apartment  4000000.0       3.0        3.0  160.0
# 2   Apartment  2250000.0       3.0        2.0  165.0
# 3   Apartment  1900000.0       3.0        2.0  230.0
# 4   Apartment  5800000.0       2.0        3.0  160.0
# 5   Apartment  1844900.0       4.0        3.0  222.0
# 6      Duplex  3900000.0       5.0        5.0  290.0
# 7   Apartment  1650000.0       2.0        2.0  144.0
# 8   Apartment  1560000.0       3.0        3.0  200.0
# 9   Apartment   992800.0       3.0        2.0  146.0
# 10  Apartment   309825.0       4.0        3.0  153.0
# 11  Apartment  1150000.0       3.0        2.0  165.0
# 12  Apartment   550000.0       2.0        1.0   94.0
# 13  Apartment  2600000.0       3.0        2.0  140.0
# 14  Apartment   800000.0       2.0        1.0  130.0

# %%
# Preparar la data para la predicción
precios_casas.preparar_data(col_objetivo = 'Price')

# %%
# Mostrar histograma de Bedrooms

precios_casas.histograma(columna='Bedrooms')

# %%
# Mostrar el histograma de Bathrooms

precios_casas.histograma(columna = 'Bathrooms')

# %%
# Mostrar el histograma de Area

precios_casas.histograma(columna = 'Area')

# %%
# Mostrar el histograma de Price (variable objetivo)

precios_casas.histograma('Price')

# %%
# Mostrar el histograma de Type

precios_casas.histograma('Type')

# %%
# Mostrar gráfico de dispersión de Bedrooms y Price

precios_casas.grafico_dispersion(x ='Bedrooms', y = 'Price')

# %%
# Mostrar el gráfico de dispersión de Bathrooms y Price

precios_casas.grafico_dispersion(x = 'Bathrooms', y = 'Price')

# %%
# Mostrar gráfico de dispersión de Area y Price

precios_casas.grafico_dispersion(x = 'Area', y = 'Price')

# %%
# Mostrar gráfico de dispersión de Type y Price

precios_casas.grafico_dispersion(x = 'Type', y = 'Price')

# %%
# Mostrar boxplot de Bedrooms

precios_casas.grafico_boxplot(columna = 'Bedrooms')

# %%
# Mostrar boxplot de Bathrooms

precios_casas.grafico_boxplot(columna = 'Bathrooms')

# %%
# Mostrar boxplot de Area

precios_casas.grafico_boxplot('Area')

# %%
# Mostrar boxplot de Price

precios_casas.grafico_boxplot('Price')

# %%
# Mostrar boxplot de Type

precios_casas.grafico_boxplot('Type')

# %%
# Mostrar matriz de correlación

precios_casas.matriz_correlacion()

# %%
# Errores de la regresión Ridge

precios_casas.Modelo_Ridge()
# Out:
# RMSE (Prueba): 4705248.5876013655
# R-squared (Prueba): 0.47697128321527793
# R-squared ajustado (Prueba): 0.4688050355926169
# Error Absoluto Medio (MAE) (Prueba): 2432840.606252367

# %%
# Errores de la regresión polinomial

precios_casas.Modelo_regresion_polinomial()
# Out:
# RMSE (Prueba): 4701489.739654386
# R-squared (Prueba): 0.47780660577281164
# R-squared ajustado (Prueba): 0.46965340036108605
# Error Absoluto Medio (MAE) (Prueba): 2433018.7717600972

# %%
# Errores regresión lineal 

precios_casas.Modelo_regresion_lineal()
# Out:
# RMSE (Prueba): 4812445.433389631
# R-squared (Prueba): 0.45286811488308265
# R-squared ajustado (Prueba): 0.45182473590310324
# Error Absoluto Medio (MAE) (Prueba): 2601778.6872391915

# %%
# Errores regresión Lasso

precios_casas.Modelo_Lasso()
# Out:
# /opt/anaconda3/envs/CA_0305/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.884e+16, tolerance: 7.904e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/CA_0305/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.884e+16, tolerance: 7.904e+13
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# Errores regresión de elsatic net 

precios_casas.Modelo_regresion_elastic_net()
# Out:
# RMSE (Prueba): 4984013.079234166
# R-squared (Prueba): 0.4131613152703222
# R-squared ajustado (Prueba): 0.41204221553415
# Error Absoluto Medio (MAE) (Prueba): 2619460.7401889665
